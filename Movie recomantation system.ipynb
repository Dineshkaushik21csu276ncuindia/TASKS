# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn

# %%
Movie = pd.read_csv("D:\\New folder (2)\\datasets\\topRated.csv")

# %%
Movie
# Out:
#       Unnamed: 0      id                        title  \
# 0              0     238                The Godfather
# 1              1     278     The Shawshank Redemption
# 2              2     240        The Godfather Part II
# 3              3     424             Schindler's List
# 4              4   19404  Dilwale Dulhania Le Jayenge
# ...          ...     ...                          ...
# 8575        8575   10208           Muppets from Space
# 8576        8576  354110                     Forsaken
# 8577        8577  183836                    The Brats
# 8578        8578   81393        12 Dates of Christmas
# 8579        8579  500268                Made in Italy
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# ...

# %%
Movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8580 entries, 0 to 8579
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    8580 non-null   int64
#  1   id            8580 non-null   int64
#  2   title         8580 non-null   object
#  3   overview      8579 non-null   object
#  4   release_date  8580 non-null   object
#  5   popularity    8580 non-null   float64
#  6   vote_average  8580 non-null   float64
#  7   vote_count    8580 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 536.4+ KB

# %%
Movie.describe
# Out:
# <bound method NDFrame.describe of       Unnamed: 0      id                        title  \
# 0              0     238                The Godfather
# 1              1     278     The Shawshank Redemption
# 2              2     240        The Godfather Part II
# 3              3     424             Schindler's List
# 4              4   19404  Dilwale Dulhania Le Jayenge
# ...          ...     ...                          ...
# 8575        8575   10208           Muppets from Space
# 8576        8576  354110                     Forsaken
# 8577        8577  183836                    The Brats
# 8578        8578   81393        12 Dates of Christmas
# 8579        8579  500268                Made in Italy
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# ...

# %%
Movie.size
# Out:
# 68640

# %%
Movie.shape
# Out:
# (8580, 8)

# %%
Movie.std
# Out:
# <bound method DataFrame.std of       Unnamed: 0      id                        title  \
# 0              0     238                The Godfather
# 1              1     278     The Shawshank Redemption
# 2              2     240        The Godfather Part II
# 3              3     424             Schindler's List
# 4              4   19404  Dilwale Dulhania Le Jayenge
# ...          ...     ...                          ...
# 8575        8575   10208           Muppets from Space
# 8576        8576  354110                     Forsaken
# 8577        8577  183836                    The Brats
# 8578        8578   81393        12 Dates of Christmas
# 8579        8579  500268                Made in Italy
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# ...

# %%
Movie.isnull().sum()
# Out:
# Unnamed: 0      0
# id              0
# title           0
# overview        1
# release_date    0
# popularity      0
# vote_average    0
# vote_count      0
# dtype: int64

# %%
Movie.duplicated
# Out:
# <bound method DataFrame.duplicated of       Unnamed: 0      id                        title  \
# 0              0     238                The Godfather
# 1              1     278     The Shawshank Redemption
# 2              2     240        The Godfather Part II
# 3              3     424             Schindler's List
# 4              4   19404  Dilwale Dulhania Le Jayenge
# ...          ...     ...                          ...
# 8575        8575   10208           Muppets from Space
# 8576        8576  354110                     Forsaken
# 8577        8577  183836                    The Brats
# 8578        8578   81393        12 Dates of Christmas
# 8579        8579  500268                Made in Italy
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# ...

# %%
Movie.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'overview', 'release_date', 'popularity',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
Movie.head()
# Out:
#    Unnamed: 0     id                        title  \
# 0           0    238                The Godfather
# 1           1    278     The Shawshank Redemption
# 2           2    240        The Godfather Part II
# 3           3    424             Schindler's List
# 4           4  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     110.790
# 1  Framed in the 1940s for the double murder of h...   1994-09-23     115.364
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      84.578
# 3  The true story of how businessman Oskar Schind...   1993-12-15      70.449
# 4  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      26.473
#
#    vote_average  vote_count
# 0           8.7       18684
# 1           8.7       24660
# 2           8.6       11298
# 3           8.6       14604
# 4           8.6        4256

# %%
Movie.tail()
# Out:
#       Unnamed: 0      id                  title  \
# 8575        8575   10208     Muppets from Space
# 8576        8576  354110               Forsaken
# 8577        8577  183836              The Brats
# 8578        8578   81393  12 Dates of Christmas
# 8579        8579  500268          Made in Italy
#
#                                                overview release_date  \
# 8575  When Gonzo's breakfast cereal tells him that h...   1999-07-14
# 8576  John Henry returns to his hometown in hopes of...   2015-09-16
# 8577  Newly engaged, Thomas meets his future father-...   2013-04-17
# 8578  In an attempt to win back her ex-boyfriend on ...   2011-12-11
# 8579  Riko is an honest and hardworking man who can ...   2018-01-25
#
#       popularity  vote_average  vote_count
# 8575      11.331           6.1         294
# 8576      12.179           6.1         310
# 8577       6.386           6.1         508
# 8578       7.827           6.1         246
# ...
